# %% [markdown]
# # LoCoMo Benchmark: Baseline vs PRIMA
#
# This notebook runs the LoCoMo benchmark comparison between baseline (no memory) and PRIMA (agentic memory) agents.
#
# Adapted from A-mem repository: https://github.com/AGI-Edgerunners/A-mem

# %%
# Install dependencies
# !pip install torch>=2.1.0 transformers==4.38.2 accelerate==0.25.0
# !pip install chromadb>=0.4.0 sentence-transformers==2.2.2
# !pip install rouge-score bert-score nltk evaluate
# !pip install numpy scipy pydantic tqdm pyyaml rich

# %%
# Clone the repository
# !git clone https://github.com/your-repo/Persistent_Mem_PRIMA.git
# %cd Persistent_Mem_PRIMA

# %%
# Download LoCoMo dataset
# !mkdir -p benchmarks/data
# Upload locomo10.json to benchmarks/data/ or download from source
# The dataset should be available at: https://github.com/AGI-Edgerunners/A-mem/tree/main/data

# %%
# Set up environment
import sys

import torch

# Add src to path
sys.path.append('src')

# Check GPU availability
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU count: {torch.cuda.device_count()}")
if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")

# %%
# Run the benchmark
# !cd benchmarks && python evaluate_benchmark.py

# %%
# Display results
import json

with open('benchmarks/benchmark_results.json', 'r') as f:
    results = json.load(f)

print("=== BASELINE RESULTS ===")
print(json.dumps(results['baseline'], indent=2))

print("\n=== PRIMA RESULTS ===")
print(json.dumps(results['prima'], indent=2))
